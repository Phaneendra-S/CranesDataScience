# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Task**

# %% [markdown]
# "https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv"

# %%
data=pd.read_csv("https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv")
data
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Deccan_Sporting      931  839.80  615    Pvt     154  Hyd    1    SPRT
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Indi_Services        954  733.00  609    Gov   13023  NCR    0    INDI
# Bangalore_Breweries  966  805.00  899    Pvt     119  Blr    1    BREW
# Bombay_Finance       899  917.00  674    Pub    1443  Mum    0    BFIN
# Chennai_Shipping     992  821.00  665    Pub     899  Che    1    SHIP
# Eastern_Estates      945  834.23  789    Pvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
#
#                           GST Start Date
# Deccan_Sporting      Services   Mar 1943
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, Deccan_Sporting to Central_Services
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Vol         11 non-null     int64
#  1   Rev         11 non-null     float64
#  2   Exp         11 non-null     int64
#  3   Sector      11 non-null     object
#  4   EmpCnt      11 non-null     int64
#  5   HQ          11 non-null     object
#  6   MNC         11 non-null     int64
#  7   StockID     11 non-null     object
#  8   GST         11 non-null     object
#  9   Start Date  11 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 968.0+ bytes

# %%
data.describe(include='all')
# Out:
#                Vol         Rev         Exp Sector        EmpCnt   HQ  \
# count    11.000000   11.000000   11.000000     11     11.000000   11
# unique         NaN         NaN         NaN      3           NaN    6
# top            NaN         NaN         NaN    Pub           NaN  NCR
# freq           NaN         NaN         NaN      5           NaN    3
# mean    940.272727  841.520909  679.909091    NaN   2310.454545  NaN
# std      28.249216   48.199894   90.097119    NaN   3605.962212  NaN
# min     899.000000  733.000000  605.000000    NaN    119.000000  NaN
# 25%     928.000000  822.500000  612.000000    NaN   1130.000000  NaN
# 50%     934.000000  839.800000  665.000000    NaN   1443.000000  NaN
# 75%     960.000000  868.950000  682.500000    NaN   1764.500000  NaN
# max     992.000000  917.000000  899.000000    NaN  13023.000000  NaN
#
#               MNC StockID       GST Start Date
# count   11.000000      11        11         11
# ...

# %%
data.iloc[1:3]
# Out:
#               Vol    Rev  Exp Sector  EmpCnt   HQ  MNC StockID       GST  \
# Kolkata_FMCG  925  874.4  676    Pub    1379  Kol    0    KFMC     Goods
# NCR_Leagles   931  863.5  605    Pub    1935  NCR    0    NCRL  Services
#
#              Start Date
# Kolkata_FMCG   Jan 1920
# NCR_Leagles    Feb 1960

# %%
data.columns
# Out:
# Index(['Vol', 'Rev', 'Exp', 'Sector', 'EmpCnt', 'HQ', 'MNC', 'StockID', 'GST',
#        'Start Date'],
#       dtype='object')

# %%
data.index
# Out:
# Index(['Deccan_Sporting', 'Kolkata_FMCG', 'NCR_Leagles', 'Bangalore_Systems',
#        'Chennai_Chemicals', 'Indi_Services', 'Bangalore_Breweries',
#        'Bombay_Finance', 'Chennai_Shipping', 'Eastern_Estates',
#        'Central_Services'],
#       dtype='object')

# %%
data.loc['Chennai_Chemicals']
# Out:
# Vol                966
# Rev              863.2
# Exp                608
# Sector             Pub
# EmpCnt            1656
# HQ                 Che
# MNC                  1
# StockID           CHEM
# GST              Goods
# Start Date    Aug 1928
# Name: Chennai_Chemicals, dtype: object

# %%
data.loc['NCR_Leagles':'Chennai_Shipping','Exp':'GST']
# Out:
#                      Exp Sector  EmpCnt   HQ  MNC StockID       GST
# NCR_Leagles          605    Pub    1935  NCR    0    NCRL  Services
# Bangalore_Systems    650    Gov    1361  Blr    0    BSYS  Services
# Chennai_Chemicals    608    Pub    1656  Che    1    CHEM     Goods
# Indi_Services        609    Gov   13023  NCR    0    INDI  Services
# Bangalore_Breweries  899    Pvt     119  Blr    1    BREW     Goods
# Bombay_Finance       674    Pub    1443  Mum    0    BFIN  Services
# Chennai_Shipping     665    Pub     899  Che    1    SHIP     Goods

# %%
data.iloc[2:9,3:9]
# Out:
#                     Sector  EmpCnt   HQ  MNC StockID       GST
# NCR_Leagles            Pub    1935  NCR    0    NCRL  Services
# Bangalore_Systems      Gov    1361  Blr    0    BSYS  Services
# Chennai_Chemicals      Pub    1656  Che    1    CHEM     Goods
# Indi_Services          Gov   13023  NCR    0    INDI  Services
# Bangalore_Breweries    Pvt     119  Blr    1    BREW     Goods
# Bombay_Finance         Pub    1443  Mum    0    BFIN  Services
# Chennai_Shipping       Pub     899  Che    1    SHIP     Goods

# %% [markdown]
# ## **sorting in data frames**

# %%
sort1=data.sort_index(axis=0, ascending=False, inplace=False)
sort1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# Indi_Services        954  733.00  609    Gov   13023  NCR    0    INDI
# Eastern_Estates      945  834.23  789    Pvt    1873  Kol    1    EEST
# Deccan_Sporting      931  839.80  615    Pvt     154  Hyd    1    SPRT
# Chennai_Shipping     992  821.00  665    Pub     899  Che    1    SHIP
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Bombay_Finance       899  917.00  674    Pub    1443  Mum    0    BFIN
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Bangalore_Breweries  966  805.00  899    Pvt     119  Blr    1    BREW
#
#                           GST Start Date
# NCR_Leagles          Services   Feb 1960
# ...

# %%
sort1=data.sort_index(axis=0, ascending=True, inplace=False)
sort1
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Bangalore_Breweries  966  805.00  899    Pvt     119  Blr    1    BREW
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Bombay_Finance       899  917.00  674    Pub    1443  Mum    0    BFIN
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Chennai_Shipping     992  821.00  665    Pub     899  Che    1    SHIP
# Deccan_Sporting      931  839.80  615    Pvt     154  Hyd    1    SPRT
# Eastern_Estates      945  834.23  789    Pvt    1873  Kol    1    EEST
# Indi_Services        954  733.00  609    Gov   13023  NCR    0    INDI
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
#
#                           GST Start Date
# Bangalore_Breweries     Goods   Oct 1971
# ...

# %%
sort1=data.sort_index(axis=1, ascending=True, inplace=False)
sort1
# Out:
#                      EmpCnt  Exp       GST   HQ  MNC     Rev Sector  \
# NCR_Leagles            1935  605  Services  NCR    0  863.50    Pub
# Kolkata_FMCG           1379  676     Goods  Kol    0  874.40    Pub
# Indi_Services         13023  609  Services  NCR    0  733.00    Gov
# Eastern_Estates        1873  789     Goods  Kol    1  834.23    Pvt
# Deccan_Sporting         154  615  Services  Hyd    1  839.80    Pvt
# Chennai_Shipping        899  665     Goods  Che    1  821.00    Pub
# Chennai_Chemicals      1656  608     Goods  Che    1  863.20    Pub
# Central_Services       1573  689  Services  NCR    1  824.00    Gov
# Bombay_Finance         1443  674  Services  Mum    0  917.00    Pub
# Bangalore_Systems      1361  650  Services  Blr    0  881.60    Gov
# Bangalore_Breweries     119  899     Goods  Blr    1  805.00    Pvt
#
#                     Start Date StockID  Vol
# NCR_Leagles           Feb 1960    NCRL  931
# Kolkata_FMCG          Jan 1920    KFMC  925
# ...

# %%
sort1=data.sort_index(axis=1, ascending=False, inplace=False)
sort1
# Out:
#                      Vol StockID Start Date Sector     Rev  MNC   HQ  \
# NCR_Leagles          931    NCRL   Feb 1960    Pub  863.50    0  NCR
# Kolkata_FMCG         925    KFMC   Jan 1920    Pub  874.40    0  Kol
# Indi_Services        954    INDI   Mar 1920    Gov  733.00    0  NCR
# Eastern_Estates      945    EEST   Jan 1994    Pvt  834.23    1  Kol
# Deccan_Sporting      931    SPRT   Mar 1943    Pvt  839.80    1  Hyd
# Chennai_Shipping     992    SHIP   Nov 1930    Pub  821.00    1  Che
# Chennai_Chemicals    966    CHEM   Aug 1928    Pub  863.20    1  Che
# Central_Services     934    CSRV   Jun 1974    Gov  824.00    1  NCR
# Bombay_Finance       899    BFIN   Apr 1925    Pub  917.00    0  Mum
# Bangalore_Systems    900    BSYS   Apr 1950    Gov  881.60    0  Blr
# Bangalore_Breweries  966    BREW   Oct 1971    Pvt  805.00    1  Blr
#
#                           GST  Exp  EmpCnt
# NCR_Leagles          Services  605    1935
# Kolkata_FMCG            Goods  676    1379
# ...

# %% [markdown]
# ## **Sort by values**

# %%
sort2=data.sort_values(by='Rev',ascending=True, inplace=False)
sort2
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Indi_Services        954  733.00  609    Gov   13023  NCR    0    INDI
# Bangalore_Breweries  966  805.00  899    Pvt     119  Blr    1    BREW
# Chennai_Shipping     992  821.00  665    Pub     899  Che    1    SHIP
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Eastern_Estates      945  834.23  789    Pvt    1873  Kol    1    EEST
# Deccan_Sporting      931  839.80  615    Pvt     154  Hyd    1    SPRT
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Bombay_Finance       899  917.00  674    Pub    1443  Mum    0    BFIN
#
#                           GST Start Date
# Indi_Services        Services   Mar 1920
# ...

# %%
sort2=data.sort_values(by='Rev',ascending=False, inplace=False)
sort2
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Bombay_Finance       899  917.00  674    Pub    1443  Mum    0    BFIN
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Deccan_Sporting      931  839.80  615    Pvt     154  Hyd    1    SPRT
# Eastern_Estates      945  834.23  789    Pvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Chennai_Shipping     992  821.00  665    Pub     899  Che    1    SHIP
# Bangalore_Breweries  966  805.00  899    Pvt     119  Blr    1    BREW
# Indi_Services        954  733.00  609    Gov   13023  NCR    0    INDI
#
#                           GST Start Date
# Bombay_Finance       Services   Apr 1925
# ...

# %%
sort2=data.sort_values(by=['Rev','Exp'],ascending=False, inplace=False)
sort2
# Out:
#                      Vol     Rev  Exp Sector  EmpCnt   HQ  MNC StockID  \
# Bombay_Finance       899  917.00  674    Pub    1443  Mum    0    BFIN
# Bangalore_Systems    900  881.60  650    Gov    1361  Blr    0    BSYS
# Kolkata_FMCG         925  874.40  676    Pub    1379  Kol    0    KFMC
# NCR_Leagles          931  863.50  605    Pub    1935  NCR    0    NCRL
# Chennai_Chemicals    966  863.20  608    Pub    1656  Che    1    CHEM
# Deccan_Sporting      931  839.80  615    Pvt     154  Hyd    1    SPRT
# Eastern_Estates      945  834.23  789    Pvt    1873  Kol    1    EEST
# Central_Services     934  824.00  689    Gov    1573  NCR    1    CSRV
# Chennai_Shipping     992  821.00  665    Pub     899  Che    1    SHIP
# Bangalore_Breweries  966  805.00  899    Pvt     119  Blr    1    BREW
# Indi_Services        954  733.00  609    Gov   13023  NCR    0    INDI
#
#                           GST Start Date
# Bombay_Finance       Services   Apr 1925
# ...

# %% [markdown]
# ## **concatenationin dataframes**

# %% [markdown]
# "https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds1.csv"

# %% [markdown]
# "https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds11.csv"

# %%
d1=pd.read_csv("https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds11.csv")
d1
# Out:
#                  Vol    Rev  Exp Sector  EmpCnt
# Kolkata_FMCG     900  874.4  676    Pub    1379
# NCR_Leagles      931  863.5  605    Pub    1935
# Bombay_Sporting  975  839.8  615    Pvt     154

# %%
d2=pd.read_csv("https://raw.githubusercontent.com/vcsgithub/vcsgithub.github.io/master/lds12.csv")
d2
# Out:
#                    Vol    Rev  Exp Sector   HQ
# Bombay_Sporting    925  839.8  715    Pvt  Mum
# Bombay_Finance     899  917.0  674    Pub  Mum
# Bangalore_Systems  931  881.6  650    Gov  Blr
# Chennai_Shipping   992  821.0  665    Pub  Che

# %%
con1=pd.concat([d1,d2])
con1
# Out:
#                    Vol    Rev  Exp Sector  EmpCnt   HQ
# Kolkata_FMCG       900  874.4  676    Pub  1379.0  NaN
# NCR_Leagles        931  863.5  605    Pub  1935.0  NaN
# Bombay_Sporting    975  839.8  615    Pvt   154.0  NaN
# Bombay_Sporting    925  839.8  715    Pvt     NaN  Mum
# Bombay_Finance     899  917.0  674    Pub     NaN  Mum
# Bangalore_Systems  931  881.6  650    Gov     NaN  Blr
# Chennai_Shipping   992  821.0  665    Pub     NaN  Che

# %%
con2=pd.concat([d1,d2],join='inner')
con2
# Out:
#                    Vol    Rev  Exp Sector
# Kolkata_FMCG       900  874.4  676    Pub
# NCR_Leagles        931  863.5  605    Pub
# Bombay_Sporting    975  839.8  615    Pvt
# Bombay_Sporting    925  839.8  715    Pvt
# Bombay_Finance     899  917.0  674    Pub
# Bangalore_Systems  931  881.6  650    Gov
# Chennai_Shipping   992  821.0  665    Pub

# %%
con3=pd.concat([d1,d2],axis=1)
# con3.drop('Bombay_Sporting', axis=0, inplace=True)
con3
# Out:
#                      Vol    Rev    Exp Sector  EmpCnt    Vol    Rev    Exp  \
# Kolkata_FMCG       900.0  874.4  676.0    Pub  1379.0    NaN    NaN    NaN
# NCR_Leagles        931.0  863.5  605.0    Pub  1935.0    NaN    NaN    NaN
# Bombay_Sporting    975.0  839.8  615.0    Pvt   154.0  925.0  839.8  715.0
# Bombay_Finance       NaN    NaN    NaN    NaN     NaN  899.0  917.0  674.0
# Bangalore_Systems    NaN    NaN    NaN    NaN     NaN  931.0  881.6  650.0
# Chennai_Shipping     NaN    NaN    NaN    NaN     NaN  992.0  821.0  665.0
#
#                   Sector   HQ
# Kolkata_FMCG         NaN  NaN
# NCR_Leagles          NaN  NaN
# Bombay_Sporting      Pvt  Mum
# Bombay_Finance       Pub  Mum
# Bangalore_Systems    Gov  Blr
# Chennai_Shipping     Pub  Che

# %%
con4=pd.concat([d1,d2],axis=1,join='inner')
con4
# Out:
#                  Vol    Rev  Exp Sector  EmpCnt  Vol    Rev  Exp Sector   HQ
# Bombay_Sporting  975  839.8  615    Pvt     154  925  839.8  715    Pvt  Mum

# %% [markdown]
# ## **rename and replace**

# %%
con1
# Out:
#                    Vol    Rev  Exp Sector
# Kolkata_FMCG       900  874.4  676    Pub
# NCR_Leagles        931  863.5  605    Pub
# Bombay_Sporting    975  839.8  615    Pvt
# Bombay_Sporting    925  839.8  715    Pvt
# Bombay_Finance     899  917.0  674    Pub
# Bangalore_Systems  931  881.6  650    Gov
# Chennai_Shipping   992  821.0  665    Pub

# %%
con1.rename(columns={"Vol":"Volume"}, inplace=True)
con1
# Out:
#                    Volume    Rev  Exp Sector  EmpCnt   HQ
# Kolkata_FMCG          900  874.4  676    Pub  1379.0  NaN
# NCR_Leagles           931  863.5  605    Pub  1935.0  NaN
# Bombay_Sporting       975  839.8  615    Pvt   154.0  NaN
# Bombay_Sporting       925  839.8  715    Pvt     NaN  Mum
# Bombay_Finance        899  917.0  674    Pub     NaN  Mum
# Bangalore_Systems     931  881.6  650    Gov     NaN  Blr
# Chennai_Shipping      992  821.0  665    Pub     NaN  Che

# %%
con1.replace('Pub','Public',inplace=True)
con1
# Out:
#                    Volume    Rev  Exp  Sector  EmpCnt   HQ
# Kolkata_FMCG          900  874.4  676  Public  1379.0  NaN
# NCR_Leagles           931  863.5  605  Public  1935.0  NaN
# Bombay_Sporting       975  839.8  615     Pvt   154.0  NaN
# Bombay_Sporting       925  839.8  715     Pvt     NaN  Mum
# Bombay_Finance        899  917.0  674     Pvt     NaN  Mum
# Bangalore_Systems     931  881.6  650     Gov     NaN  Blr
# Chennai_Shipping      992  821.0  665     Gov     NaN  Che

# %% [markdown]
# ## **Task**

# %%
data=pd.read_csv(r"C:\Users\PHANEENDRA\Downloads\Toyota.csv",index_col=0,na_values=['??','????'])
data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %% [markdown]
# **Data Cleaning**

# %%
data.shape
# Out:
# (1436, 10)

# %%
data.size
# Out:
# 14360

# %%
data.ndim
# Out:
# 2

# %%
data.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3  14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5  12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# 6  16900  27.0      NaN   Diesel    NaN       NaN          0  2000      3
# 7  18600  30.0  75889.0      NaN   90.0       1.0          0  2000      3
# 8  21500  27.0  19700.0   Petrol  192.0       0.0          0  1800      3
# 9  12950  23.0  71138.0   Diesel    NaN       NaN          0  1900      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170
# 5    1170
# 6    1245
# 7    1245
# 8    1185
# 9    1105

# %%
data.loc[:,['FuelType','CC']]
# Out:
#      FuelType    CC
# 0      Diesel  2000
# 1      Diesel  2000
# 2      Diesel  2000
# 3      Diesel  2000
# 4      Diesel  2000
# ...       ...   ...
# 1431   Petrol  1300
# 1432   Petrol  1300
# 1433   Petrol  1300
# 1434      NaN  1300
# 1435   Petrol  1600
#
# [1436 rows x 2 columns]

# %%
data.loc[50:101, 'FuelType':'Automatic']
# Out:
#     FuelType     HP  MetColor  Automatic
# 50    Diesel   90.0       1.0          0
# 51    Petrol   97.0       1.0          0
# 52    Petrol  110.0       1.0          1
# 53    Petrol  192.0       1.0          0
# 54    Petrol  110.0       0.0          1
# 55    Petrol  110.0       1.0          0
# 56    Petrol   97.0       0.0          0
# 57    Petrol   97.0       0.0          0
# 58    Petrol  110.0       1.0          1
# 59    Petrol  110.0       1.0          0
# 60       NaN   97.0       1.0          0
# 61    Petrol  110.0       NaN          0
# 62    Petrol  110.0       1.0          0
# 63    Petrol  110.0       1.0          0
# 64    Petrol   97.0       1.0          0
# 65    Petrol  110.0       1.0          0
# 66    Petrol  110.0       1.0          0
# 67    Petrol   97.0       1.0          0
# 68    Diesel  110.0       1.0          0
# 69    Petrol   97.0       NaN          0
# 70    Petrol   97.0       1.0          0
# 71    Petrol   97.0       1.0          0
# ...

# %%
data.head(15)
# Out:
#     Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0   13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1   13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2   13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3   14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4   13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5   12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# 6   16900  27.0      NaN   Diesel    NaN       NaN          0  2000      3
# 7   18600  30.0  75889.0      NaN   90.0       1.0          0  2000      3
# 8   21500  27.0  19700.0   Petrol  192.0       0.0          0  1800      3
# 9   12950  23.0  71138.0   Diesel    NaN       NaN          0  1900      3
# 10  20950  25.0  31461.0   Petrol  192.0       0.0          0  1800      3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 155.7+ KB

# %%
data["Doors"].unique()
# Out:
# array(['three', '3', '5', '4', 'four', 'five', '2'], dtype=object)

# %%
data.replace('three',3, inplace=True)
data.replace('four',4, inplace=True)
data.replace('five',5, inplace=True)
data["Doors"].unique()
# Out:
# array([3, '3', '5', '4', 4, 5, '2'], dtype=object)

# %%
data["Doors"]=data["Doors"].astype("int64")

# %%
data["Doors"].unique()
# Out:
# array([3, 5, 4, 2], dtype=int64)

# %%
data.dtypes
# Out:
# Price          int64
# Age          float64
# KM           float64
# FuelType      object
# HP           float64
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors          int64
# Weight         int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
data["FuelType"].unique()
# Out:
# array(['Diesel', nan, 'Petrol', 'CNG'], dtype=object)

# %%
data["FuelType"]=data["FuelType"].fillna(data["FuelType"].bfill())
data.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType       0
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
data["Age"].unique()
# Out:
# array([23., 24., 26., 30., 32., 27., 25., 22., 31., 28., 29., nan, 20.,
#        19., 17., 11., 18., 13., 14.,  4.,  8.,  7., 16., 15., 10., 12.,
#         9.,  6.,  2.,  1., 43., 38., 40., 44., 41., 37., 39., 42., 35.,
#        34., 33., 36., 53., 51., 54., 45., 55., 48., 52., 49., 56., 50.,
#        47., 46., 58., 68., 59., 62., 65., 67., 64., 60., 61., 66., 57.,
#        63., 73., 79., 78., 74., 77., 69., 80., 76., 70., 71., 75., 72.])

# %%
data["Age"]=data["Age"].fillna(data["Age"].mean())
data.isnull().sum()
# Out:
# Price          0
# Age            0
# KM            15
# FuelType       0
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
data.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000      3
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
data["KM"]=data["KM"].fillna(data["KM"].mean())
data.isnull().sum()
# Out:
# Price          0
# Age            0
# KM             0
# FuelType       0
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
data["HP"]=data["HP"].fillna(data["HP"].mean())
data.isnull().sum()
# Out:
# Price          0
# Age            0
# KM             0
# FuelType       0
# HP             0
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
data["MetColor"].value_counts()
# Out:
# MetColor
# 1.0    868
# 0.0    418
# Name: count, dtype: int64

# %%
data["MetColor"]=data["MetColor"].fillna(data["MetColor"].bfill())
data.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
data.shape
# Out:
# (1436, 10)

# %% [markdown]
# **Exporting to excel format**

# %%
data.to_excel("car_clear.xlsx")

# %%
car=pd.read_excel("car_clear.xlsx")
car
# Out:
#       Unnamed: 0  Price   Age       KM FuelType     HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90.0       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90.0       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90.0       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90.0       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90.0       0.0          0
# ...          ...    ...   ...      ...      ...    ...       ...        ...
# 1431        1431   7500   NaN  20544.0   Petrol   86.0       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86.0       0.0          0
# 1433        1433   8500   NaN  17016.0   Petrol   86.0       0.0          0
# 1434        1434   7250  70.0      NaN      NaN   86.0       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110.0       0.0          0
#
#         CC  Doors  Weight
# 0     2000  three    1165
# ...

# %%
car.to_csv("car_csv.csv")

# %%
car2=pd.read_csv("car_csv.csv")
car2
# Out:
#       Unnamed: 0.1  Unnamed: 0  Price   Age       KM FuelType     HP  \
# 0                0           0  13500  23.0  46986.0   Diesel   90.0
# 1                1           1  13750  23.0  72937.0   Diesel   90.0
# 2                2           2  13950  24.0  41711.0   Diesel   90.0
# 3                3           3  14950  26.0  48000.0   Diesel   90.0
# 4                4           4  13750  30.0  38500.0   Diesel   90.0
# ...            ...         ...    ...   ...      ...      ...    ...
# 1431          1431        1431   7500   NaN  20544.0   Petrol   86.0
# 1432          1432        1432  10845  72.0      NaN   Petrol   86.0
# 1433          1433        1433   8500   NaN  17016.0   Petrol   86.0
# 1434          1434        1434   7250  70.0      NaN      NaN   86.0
# 1435          1435        1435   6950  76.0      1.0   Petrol  110.0
#
#       MetColor  Automatic    CC  Doors  Weight
# 0          1.0          0  2000  three    1165
# ...

# %%
car.insert(11, "Price_Class","")
car.head()
# Out:
#    Unnamed: 0  Price   Age       KM FuelType    HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000
# 1           1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000
# 2           2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000
# 3           3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000
# 4           4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000
#
#    Doors  Weight Price_Class
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
print(len(car))
# Out:
# 1436

# %%
for i in range(len(car)):
    if car["Price"][i] < 8500:
        car["Price_Class"][i]="Low"
    elif car["Price"][i] > 11990:
        car["Price_Class"][i]="High"
    else:
        car["Price_Class"][i]="Medium"

car.head(100)
# Out:
#     Unnamed: 0  Price   Age       KM FuelType     HP  MetColor  Automatic  \
# 0            0  13500  23.0  46986.0   Diesel   90.0       1.0          0
# 1            1  13750  23.0  72937.0   Diesel   90.0       1.0          0
# 2            2  13950  24.0  41711.0   Diesel   90.0       NaN          0
# 3            3  14950  26.0  48000.0   Diesel   90.0       0.0          0
# 4            4  13750  30.0  38500.0   Diesel   90.0       0.0          0
# ..         ...    ...   ...      ...      ...    ...       ...        ...
# 95          95  19950  17.0  30351.0   Diesel   90.0       1.0          0
# 96          96  15950  19.0  29435.0   Petrol   97.0       1.0          0
# 97          97  15950  19.0  25948.0   Petrol   97.0       1.0          0
# 98          98  18750  11.0  24500.0   Petrol  110.0       NaN          0
# 99          99  17450  18.0  23902.0   Petrol   97.0       1.0          0
#
#       CC  Doors  Weight Price_Class
# 0   2000  three    1165        High
# ...

# %%
car.insert(12, "Age_in_yrs","")
car.head()
# Out:
#    Unnamed: 0  Price   Age       KM FuelType    HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000
# 1           1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000
# 2           2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000
# 3           3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000
# 4           4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000
#
#    Doors  Weight Price_Class Age_in_yrs
# 0  three    1165        High
# 1      3    1165        High
# 2      3    1165        High
# 3      3    1165        High
# 4      3    1170        High

# %%
def age_to_yrs(value):
    val_con=value/12
    return val_con

# %%
car["Age_in_yrs"]=age_to_yrs(car["Age"])
car
# Out:
#       Unnamed: 0  Price   Age       KM FuelType     HP  MetColor  Automatic  \
# 0              0  13500  23.0  46986.0   Diesel   90.0       1.0          0
# 1              1  13750  23.0  72937.0   Diesel   90.0       1.0          0
# 2              2  13950  24.0  41711.0   Diesel   90.0       NaN          0
# 3              3  14950  26.0  48000.0   Diesel   90.0       0.0          0
# 4              4  13750  30.0  38500.0   Diesel   90.0       0.0          0
# ...          ...    ...   ...      ...      ...    ...       ...        ...
# 1431        1431   7500   NaN  20544.0   Petrol   86.0       1.0          0
# 1432        1432  10845  72.0      NaN   Petrol   86.0       0.0          0
# 1433        1433   8500   NaN  17016.0   Petrol   86.0       0.0          0
# 1434        1434   7250  70.0      NaN      NaN   86.0       1.0          0
# 1435        1435   6950  76.0      1.0   Petrol  110.0       0.0          0
#
#         CC  Doors  Weight Price_Class  Age_in_yrs
# ...

# %%
avg_price_by_fuel_type=data.groupby('FuelType')['Price'].mean()
avg_price_by_fuel_type
# Out:
# FuelType
# CNG        9584.000000
# Diesel    10889.277778
# Petrol    10689.927782
# Name: Price, dtype: float64
