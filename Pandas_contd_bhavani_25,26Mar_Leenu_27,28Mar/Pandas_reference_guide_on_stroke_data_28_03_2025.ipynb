# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\PHANEENDRA\Downloads\stroke.csv")
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %% [markdown]
# ## 1.Data Exploration & Summary

# %% [markdown]
# **Basic Info**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail(5)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %% [markdown]
# **Handling Missing Values**

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.dropna()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.fillna(df['bmi'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# **Data Types &amp; Conversion**

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df['age']=df['age'].astype('int64')

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                    int64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# ## 2.Data Selection & filtering

# %%
df['id']
# Out:
# 0        9046
# 1       51676
# 2       31112
# 3       60182
# 4        1665
#         ...
# 5105    18234
# 5106    44873
# 5107    19723
# 5108    37544
# 5109    44679
# Name: id, Length: 5110, dtype: int64

# %%
df[['id','ever_married']]
# Out:
#          id ever_married
# 0      9046          Yes
# 1     51676          Yes
# 2     31112          Yes
# 3     60182          Yes
# 4      1665          Yes
# ...     ...          ...
# 5105  18234          Yes
# 5106  44873          Yes
# 5107  19723          Yes
# 5108  37544          Yes
# 5109  44679          Yes
#
# [5110 rows x 2 columns]

# %%
df[df['id']<100]
# Out:
#       id  gender  age  hypertension  heart_disease ever_married work_type  \
# 805   99  Female   31             0              0           No   Private
# 1010  84    Male   55             0              0          Yes   Private
# 2333  77  Female   13             0              0           No  children
# 2528  91  Female   42             0              0           No   Private
# 4230  67  Female   17             0              0           No   Private
#
#      Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 805           Urban             108.89  52.300000          Unknown       0
# 1010          Urban              89.17  31.500000     never smoked       0
# 2333          Rural              85.81  18.600000          Unknown       0
# 2528          Urban              98.53  18.500000     never smoked       0
# 4230          Urban              92.97  28.893237  formerly smoked       0

# %%
df[(df['id']<100)&(df['age']<20)]
# Out:
#       id  gender  age  hypertension  heart_disease ever_married work_type  \
# 2333  77  Female   13             0              0           No  children
# 4230  67  Female   17             0              0           No   Private
#
#      Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 2333          Rural              85.81  18.600000          Unknown       0
# 4230          Urban              92.97  28.893237  formerly smoked       0

# %%
df.query("id < 100 and age < 20")
# Out:
#       id  gender  age  hypertension  heart_disease ever_married work_type  \
# 2333  77  Female   13             0              0           No  children
# 4230  67  Female   17             0              0           No   Private
#
#      Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 2333          Rural              85.81  18.600000          Unknown       0
# 4230          Urban              92.97  28.893237  formerly smoked       0

# %% [markdown]
# ## 3.Aggregation & Grouping

# %% [markdown]
# **Grouping**

# %%
df.groupby('age')['bmi'].mean()
# Out:
# age
# 0     18.425424
# 1     19.319041
# 2     19.089091
# 3     19.064923
# 4     18.100000
#         ...
# 78    28.014109
# 79    27.959363
# 80    28.788282
# 81    27.951667
# 82    28.044522
# Name: bmi, Length: 83, dtype: float64

# %%
df.groupby('gender').agg({'bmi':['mean','sum','std']})
# Out:
#               bmi
#              mean           sum       std
# gender
# Female  29.060168  87006.143980  7.978328
# Male    28.659998  60615.896639  7.278760
# Other   22.400000     22.400000       NaN

# %% [markdown]
# **Pivot Tables**

# %%
df.pivot_table(index='age', columns='gender', values='bmi',aggfunc='mean')
# Out:
# gender     Female       Male  Other
# age
# 0       17.793333  18.764044    NaN
# 1       18.397458  20.424941    NaN
# 2       18.988462  19.179310    NaN
# 3       18.799767  19.517249    NaN
# 4       18.145455  18.078261    NaN
# ..            ...        ...    ...
# 78      28.386329  27.482367    NaN
# 79      27.999541  27.868190    NaN
# 80      28.506660  29.210714    NaN
# 81      28.110526  27.677273    NaN
# 82      28.114947  27.943478    NaN
#
# [83 rows x 3 columns]

# %% [markdown]
# ## 4.Sorting & Ranking

# %%
df.sort_values(by='avg_glucose_level', ascending=True)
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 4886  60562  Female   21             0              0           No
# 1191  37404    Male   42             0              0          Yes
# 4110  43028    Male   66             0              0          Yes
# 682   61300    Male   20             0              0           No
# 772   72547    Male   61             0              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 2462  27626  Female   60             0              0           No
# 4983  10995    Male   76             1              0          Yes
# 3088  26267  Female   76             0              0          Yes
# 1207  22440  Female   49             0              0          Yes
# 193   69112    Male   68             1              1          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 4886        Private          Rural              55.12  21.8     never smoked
# ...

# %%
df.sort_values(by=['avg_glucose_level','age'], ascending=[True,True])
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 4886  60562  Female   21             0              0           No
# 1191  37404    Male   42             0              0          Yes
# 4110  43028    Male   66             0              0          Yes
# 682   61300    Male   20             0              0           No
# 772   72547    Male   61             0              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 2462  27626  Female   60             0              0           No
# 4983  10995    Male   76             1              0          Yes
# 3088  26267  Female   76             0              0          Yes
# 1207  22440  Female   49             0              0          Yes
# 193   69112    Male   68             1              1          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 4886        Private          Rural              55.12  21.8     never smoked
# ...

# %%
df['rank']=df['bmi'].rank()

# %%
df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %% [markdown]
# ## 5.Data Transformation &amp; Feature Engineering

# %%
df['no.of problems']=df['hypertension']+df['heart_disease']+df['stroke']

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke', 'rank', 'no.of problems'],
#       dtype='object')

# %%
import numpy as np

# %%
df['log_col']=np.log(df['bmi'])

# %%
df
# Out:
#          id  gender  age  hypertension  heart_disease ever_married  \
# 0      9046    Male   67             0              1          Yes
# 1     51676  Female   61             0              0          Yes
# 2     31112    Male   80             0              1          Yes
# 3     60182  Female   49             0              0          Yes
# 4      1665  Female   79             1              0          Yes
# ...     ...     ...  ...           ...            ...          ...
# 5105  18234  Female   80             1              0          Yes
# 5106  44873  Female   81             0              0          Yes
# 5107  19723  Female   35             0              0          Yes
# 5108  37544    Male   51             0              0          Yes
# 5109  44679  Female   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
df['id']=df['id'].apply(lambda x:x//2)

# %%
df['gender']=df['gender'].map({'Male':'M','Female':'F','Other':'Trans'})

# %%
df['gender'].unique()
# Out:
# array(['M', 'F', 'Trans'], dtype=object)

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## 6.Merging & Joining DataFrames

# %%
df1=df.copy()
df1
# Out:
#          id gender  age  hypertension  heart_disease ever_married  \
# 0      4523      M   67             0              1          Yes
# 1     25838      F   61             0              0          Yes
# 2     15556      M   80             0              1          Yes
# 3     30091      F   49             0              0          Yes
# 4       832      F   79             1              0          Yes
# ...     ...    ...  ...           ...            ...          ...
# 5105   9117      F   80             1              0          Yes
# 5106  22436      F   81             0              0          Yes
# 5107   9861      F   35             0              0          Yes
# 5108  18772      M   51             0              0          Yes
# 5109  22339      F   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
df.merge(df1,on='id',how='inner')
# Out:
#          id gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 0      4523        M     67               0                1            Yes
# 1     25838        F     61               0                0            Yes
# 2     15556        M     80               0                1            Yes
# 3     15556        M     80               0                1            Yes
# 4     30091        F     49               0                0            Yes
# ...     ...      ...    ...             ...              ...            ...
# 5451  22436        F     81               0                0            Yes
# 5452   9861        F     35               0                0            Yes
# 5453  18772        M     51               0                0            Yes
# 5454  18772        M     51               0                0            Yes
# 5455  22339        F     44               0                0            Yes
#
# ...

# %%
df.merge(df1,on='id',how='left')
# Out:
#          id gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 0      4523        M     67               0                1            Yes
# 1     25838        F     61               0                0            Yes
# 2     15556        M     80               0                1            Yes
# 3     15556        M     80               0                1            Yes
# 4     30091        F     49               0                0            Yes
# ...     ...      ...    ...             ...              ...            ...
# 5451  22436        F     81               0                0            Yes
# 5452   9861        F     35               0                0            Yes
# 5453  18772        M     51               0                0            Yes
# 5454  18772        M     51               0                0            Yes
# 5455  22339        F     44               0                0            Yes
#
# ...

# %%
pd.concat([df,df1],axis=0)
# Out:
#          id gender  age  hypertension  heart_disease ever_married  \
# 0      4523      M   67             0              1          Yes
# 1     25838      F   61             0              0          Yes
# 2     15556      M   80             0              1          Yes
# 3     30091      F   49             0              0          Yes
# 4       832      F   79             1              0          Yes
# ...     ...    ...  ...           ...            ...          ...
# 5105   9117      F   80             1              0          Yes
# 5106  22436      F   81             0              0          Yes
# 5107   9861      F   35             0              0          Yes
# 5108  18772      M   51             0              0          Yes
# 5109  22339      F   44             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  36.600000
# ...

# %%
pd.concat([df,df1],axis=1)
# Out:
#          id gender  age  hypertension  heart_disease ever_married  \
# 0      4523      M   67             0              1          Yes
# 1     25838      F   61             0              0          Yes
# 2     15556      M   80             0              1          Yes
# 3     30091      F   49             0              0          Yes
# 4       832      F   79             1              0          Yes
# ...     ...    ...  ...           ...            ...          ...
# 5105   9117      F   80             1              0          Yes
# 5106  22436      F   81             0              0          Yes
# 5107   9861      F   35             0              0          Yes
# 5108  18772      M   51             0              0          Yes
# 5109  22339      F   44             0              0          Yes
#
#           work_type  Residence_type  avg_glucose_level        bmi  ...  \
# 0           Private           Urban             228.69  36.600000  ...
# ...

# %% [markdown]
# ## Data Visualization with Pandas

# %%
import matplotlib.pyplot as pyplot

# %%
df['avg_glucose_level'].hist()
# Out:
# <Axes: >

# %%
df.plot(kind='bar', x='gender', y='bmi')
# Out:
# <Axes: xlabel='gender'>
