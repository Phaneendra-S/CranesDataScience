# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\PHANEENDRA\Downloads\Copy of imdb_data.csv")
df.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
# ...

# %%
df.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %% [markdown]
# **iloc**
# - *iloc* gets rows (or columns) at particular positions in the index ( so it only takes integers)

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.iloc[0:5,0:3]
# Out:
#    id                              belongs_to_collection    budget
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0

# %%
df.iloc[:,-2:]
# Out:
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [3000 rows x 2 columns]

# %%
#print rows from 150 to 175 and print the last 5th column to last 3rd column
df.iloc[150:176,-5:-2]
# Out:
#                                         title  \
# 150                                Windwalker
# 151                                 Holy Hell
# 152                                Paperhouse
# 153                         The Boy Next Door
# 154                                 Vigilante
# 155                      Return to Never Land
# 156                              Shadowboxing
# 157            American Cyborg: Steel Warrior
# 158                                Get Carter
# 159                    The Quick and the Dead
# 160                            Winter Passing
# 161                               Casual Sex?
# 162                      Your Sister's Sister
# 163                                  Rushmore
# 164                               The Reaping
# 165                        Ghosts Can't Do It
# 166                             Koyaanisqatsi
# 167                The Exorcism of Emily Rose
# 168            The Return of the Pink Panther
# ...

# %%
#print last 5 rows and first 10 columns
df.iloc[-5:,:10]
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# ...

# %%
#print from last 10th row to last 2nd row and last 5 columns
df.iloc[-10:-1,-5:]
# Out:
#                         title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
#
#                                                Keywords  \
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2991  [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
#
#                                                    cast  \
# ...

# %%
#print rows from 195th index till last 5th row and print all the columns
# df.iloc[195:2996]
# df.iloc[-2805:-4]
df.iloc[195:-4]
# Out:
#         id                              belongs_to_collection    budget  \
# 195    196                                                NaN         0
# 196    197                                                NaN   7000000
# 197    198                                                NaN  60000000
# 198    199                                                NaN  24000000
# 199    200                                                NaN  12600000
# ...    ...                                                ...       ...
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
#
#                                                  genres  \
# ...

# %%
#print all rows except last 150 rows and all columns except first 7 columns
df.iloc[:-150,7:]
# Out:
#                                          original_title  \
# 0                                Hot Tub Time Machine 2
# 1              The Princess Diaries 2: Royal Engagement
# 2                                              Whiplash
# 3                                               Kahaani
# 4                                                  마린보이
# ...                                                 ...
# 2845  Who Is Harry Nilsson (And Why Is Everybody Tal...
# 2846                                             Robots
# 2847                                                '71
# 2848                                        Jersey Boys
# 2849                                            Стиляги
#
#                                                overview  popularity  \
# 0     When Lou, who has become the "father of the In...    6.575393
# 1     Mia Thermopolis is now a college graduate and ...    8.248895
# 2     Under the direction of a ruthless instructor, ...   64.299990
# ...

# %%
#print all the rows and columns from first 3rd column till last 3rd column
df.iloc[:,2:-2]
# Out:
#         budget                                             genres  \
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4            0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...        ...                                                ...
# 2995         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# ...

# %% [markdown]
# **loc**
# - *loc* gets rows (or columns) with particular labels from the index

# %%
"""we can use particular row name(but here in this example we 
  don't have any particular names for names so we are using indices)"""
df.loc[40:50,['genres']]   #here last index also will be considered
# Out:
#                                                genres
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 41  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 42                     [{'id': 35, 'name': 'Comedy'}]
# 43                      [{'id': 18, 'name': 'Drama'}]
# 44  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 45  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 47  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 48  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 49  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 50  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...

# %%
#using loc extract last 10 rows and the following columns - original_title,production_companies, revenue
df.loc[2990:,['original_title','production_companies', 'revenue']]
# Out:
#                original_title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                    production_companies    revenue
# 2990  [{'name': 'New Line Cinema', 'id': 12}, {'name...    7240837
# 2991  [{'name': 'MTV Films', 'id': 746}, {'name': 'C...   91038276
# 2992  [{'name': 'Douglas Fairbanks Pictures', 'id': ...    1213880
# 2993  [{'name': 'DreamWorks SKG', 'id': 27}, {'name'...  219417255
# 2994          [{'name': 'Paramount Pictures', 'id': 4}]   14715067
# 2995  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...    1596687
# 2996  [{'name': 'Memfis Film', 'id': 321}, {'name': ...     180590
# 2997  [{'name': 'New Line Cinema', 'id': 12}, {'name...   89456761
# ...

# %%
#using loc function extract first 11 rows and the following columns-'id','overview','Keywords','cast'
df.loc[:10,['id','overview','Keywords','cast']]
# Out:
#     id                                           overview  \
# 0    1  When Lou, who has become the "father of the In...
# 1    2  Mia Thermopolis is now a college graduate and ...
# 2    3  Under the direction of a ruthless instructor, ...
# 3    4  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# 4    5  Marine Boy is the story of a former national s...
# 5    6  Pinocchio and his friends, a glow worm and a m...
# 6    7  A young girl buys an antique box at a yard sal...
# 7    8  A chronicle which provides a rare window into ...
# 8    9  After telling the story of Flint's last journe...
# 9   10  In "A Mighty Wind", director Christopher Guest...
# 10  11  When world heavyweight boxing champion, Apollo...
#
#                                              Keywords  \
# 0   [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1   [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# ...

# %%
df['profit']=df['revenue']-df['budget']
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit'],
#       dtype='object')

# %%
df['release_date'].value_counts()
# Out:
# release_date
# 9/10/10     5
# 9/10/15     5
# 9/7/07      4
# 12/22/95    4
# 11/1/12     4
#            ..
# 5/6/88      1
# 11/19/04    1
# 12/21/11    1
# 9/11/12     1
# 9/22/11     1
# Name: count, Length: 2398, dtype: int64

# %%
# Convert 'date' column to datetime
df['release_date'] = pd.to_datetime(df['release_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
#
df['half_runtime']=df['runtime']/2
df.head(1)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
#
#                            genres homepage    imdb_id original_language  \
# 0  [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294                en
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
#
#    popularity  ...                          spoken_languages    status  \
# 0    6.575393  ...  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
#
#                                                 cast  \
# ...

# %%
#axis=1 is for column operation and 0 is for row operation
#inplace=True changes the original df
df.drop('half_runtime',axis=1,inplace=True)
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df['status'].value_counts()
# Out:
# status
# Released    2996
# Rumored        4
# Name: count, dtype: int64

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
df['original_language']=='en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
english_movies=df[df['original_language']=='en']
english_movies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# ...

# %%
#extract the details of 'hi' language movies
hindi_movies=df[df['original_language']=='hi']
hindi_movies.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 213  214                   NaN   6700000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                     [{'id': 28, 'name': 'Action'}]
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 213                              NaN  tt2077833                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'profit'],
#       dtype='object')

# %%
long_movies=df[df['runtime']>120]

# %%
long_movies.shape
# Out:
# (657, 24)

# %%
#findout how many short(<=120) english movies are there in the dataset
shortEnglishMovies = df[(df['original_language']=='en') & (df['runtime']<=120)]
shortEnglishMovies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# ...

# %%
shortEnglishMovies.shape
# Out:
# (2069, 24)

# %%
#extract the details of long non english movies
long_non_eng=df[(df['original_language']!='en') & (df['runtime']>120)]
long_non_eng.head()
# Out:
#     id belongs_to_collection   budget  \
# 3    4                   NaN  1200000
# 67  68                   NaN        0
# 71  72                   NaN        0
# 76  77                   NaN   500000
# 97  98                   NaN        0
#
#                                                genres  \
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 67                      [{'id': 18, 'name': 'Drama'}]
# 71                      [{'id': 18, 'name': 'Drama'}]
# 76  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
#
#                                   homepage    imdb_id original_language  \
# 3               http://kahaanithefilm.com/  tt1821480                hi
# 67                                     NaN  tt2852400                zh
# 71  http://www.motorcyclediariesmovie.com/  tt0318462                es
# 76                                     NaN  tt0242572                ta
# ...

# %%
long_non_eng.shape[0]
# Out:
# 151

# %%
#find out how many movies in the dataset is a flop in the theatre
flopMovies=df[df['profit']<0]
flopMovies.head()
# Out:
#     id                              belongs_to_collection    budget  \
# 0    1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 5    6                                                NaN   8000000
# 15  16                                                NaN    500000
# 18  19                                                NaN   8000000
# 27  28                                                NaN  11000000
#
#                                                genres  \
# 0                      [{'id': 35, 'name': 'Comedy'}]
# 5   [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 18  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 27  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                                  homepage    imdb_id original_language  \
# 0                                     NaN  tt2637294                en
# 5                                     NaN  tt0093743                en
# ...

# %%
flopMovies.shape[0]
# Out:
# 655

# %%
#findout the details of moves that are not released in the theatre
df['status'].value_counts()
# Out:
# status
# Released    2996
# Rumored        4
# Name: count, dtype: int64

# %%
not_released=df[df['status']!='Released']
not_released.head()
# Out:
#         id                              belongs_to_collection  budget  \
# 609    610  [{'id': 144200, 'name': 'Swan Princess Series'...       0
# 1007  1008                                                NaN       0
# 1216  1217                                                NaN       0
# 1618  1619                                                NaN  891000
#
#                                                  genres homepage    imdb_id  \
# 609   [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...      NaN  tt0120254
# 1007                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt1860180
# 1216  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN  tt0091024
# 1618                [{'id': 99, 'name': 'Documentary'}]      NaN  tt0145394
#
#      original_language                                  original_title  \
# 609                 en  The Swan Princess: Escape from Castle Mountain
# 1007                en                         Billy Gardell: Halftime
# ...
